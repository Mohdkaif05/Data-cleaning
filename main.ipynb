# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
df=pd.read_csv("netflix1.csv")

# %%
df.head(5)
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.shape
# Out:
# (8790, 10)

# %%
df.info() # this will give the information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
# rating feature is not useful . so it is wise to remove this.
df.drop("rating",axis=1,inplace=True)

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year   duration  \
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'duration', 'listed_in'],
#       dtype='object')

# %%
# to make first letter of every column name capital letter.
new_columns=[]
for i in df.columns : 
    new_columns.append(i.capitalize())
new_columns
# Out:
# ['Show_id',
#  'Type',
#  'Title',
#  'Director',
#  'Country',
#  'Date_added',
#  'Release_year',
#  'Duration',
#  'Listed_in']

# %%
df.columns=new_columns

# %%
df.head(3)
# Out:
#   Show_id     Type                 Title         Director        Country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
# 2      s6  TV Show         Midnight Mass    Mike Flanagan  United States
#
#   Date_added  Release_year  Duration  \
# 0  9/25/2021          2020    90 min
# 1  9/24/2021          2021  1 Season
# 2  9/24/2021          2021  1 Season
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Hence there is no duplicate values in the daraset

# %%
df.isna().sum()
# Out:
# Show_id         0
# Type            0
# Title           0
# Director        0
# Country         0
# Date_added      0
# Release_year    0
# Duration        0
# Listed_in       0
# dtype: int64

# %% [markdown]
# there is no missing value in the  dataset

# %%
df.head()
# Out:
#   Show_id     Type                             Title         Director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year  Duration  \
# 0  United States  9/25/2021          2020    90 min
# 1         France  9/24/2021          2021  1 Season
# 2  United States  9/24/2021          2021  1 Season
# 3         Brazil  9/22/2021          2021    91 min
# 4  United States  9/24/2021          1993   125 min
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# ...

# %%
df.replace({"Show_id":"[A-Z,a-z]"}," ", regex=True,inplace=True)
df.head()
# Out:
#   Show_id     Type                             Title         Director  \
# 0       1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1       3  TV Show                         Ganglands  Julien Leclercq
# 2       6  TV Show                     Midnight Mass    Mike Flanagan
# 3      14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4       8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year  Duration  \
# 0  United States  9/25/2021          2020    90 min
# 1         France  9/24/2021          2021  1 Season
# 2  United States  9/24/2021          2021  1 Season
# 3         Brazil  9/22/2021          2021    91 min
# 4  United States  9/24/2021          1993   125 min
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# ...

# %%
df["Date_added"]=pd.to_datetime(df["Date_added"] )
df.head()
# Out:
#   Show_id     Type                             Title         Director  \
# 0       1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1       3  TV Show                         Ganglands  Julien Leclercq
# 2       6  TV Show                     Midnight Mass    Mike Flanagan
# 3      14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4       8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year  Duration  \
# 0  United States 2021-09-25          2020    90 min
# 1         France 2021-09-24          2021  1 Season
# 2  United States 2021-09-24          2021  1 Season
# 3         Brazil 2021-09-22          2021    91 min
# 4  United States 2021-09-24          1993   125 min
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# ...

# %%
# changing datatype od Show_id to integer
df["Show_id"]=df["Show_id"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_id       8790 non-null   int32
#  1   Type          8790 non-null   object
#  2   Title         8790 non-null   object
#  3   Director      8790 non-null   object
#  4   Country       8790 non-null   object
#  5   Date_added    8790 non-null   datetime64[ns]
#  6   Release_year  8790 non-null   int64
#  7   Duration      8790 non-null   object
#  8   Listed_in     8790 non-null   object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(6)
# memory usage: 583.8+ KB

# %%
df_country=df["Country"].value_counts().reset_index()
df_country
# Out:
#            Country  count
# 0    United States   3240
# 1            India   1057
# 2   United Kingdom    638
# 3         Pakistan    421
# 4        Not Given    287
# ..             ...    ...
# 81            Iran      1
# 82    West Germany      1
# 83          Greece      1
# 84        Zimbabwe      1
# 85    Soviet Union      1
#
# [86 rows x 2 columns]

# %%
df_country[df_country["Country"]=="Turkey"]
# Out:
#    Country  count
# 13  Turkey    112

# %%
## exporting clean data to csv file
df.to_csv("cleaned_netflix_data.csv")
